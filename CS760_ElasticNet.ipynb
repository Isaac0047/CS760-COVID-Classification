# %%
import numpy as np
import scipy.io
import sklearn
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split

# %%
mat = scipy.io.loadmat('Feature_all_sig.mat')
# mat = scipy.io.loadmat('Feature_stat_tex_fftnorm')
mat['Feature_all_sig'].shape
# mat['Feature'].shape
print(mat)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Sun Dec  6 19:08:00 2020', '__version__': '1.0', '__globals__': [], 'Feature_all_sig': array([[ 1.47646175e+01,  1.90000000e+02, -0.00000000e+00, ...,
#          8.82521391e+01,  1.57500000e+02, -7.94858269e-02],
#        [ 1.67558975e+01,  1.96000000e+02, -0.00000000e+00, ...,
#          7.21088746e+01,  1.82000000e+02, -4.57667670e-01],
#        [ 1.61851075e+01,  1.95000000e+02, -0.00000000e+00, ...,
#          7.50259556e+01,  1.81000000e+02, -3.70201584e-01],
#        ...,
#        [ 1.65925425e+01,  2.08000000e+02, -0.00000000e+00, ...,
#          9.12710383e+01,  1.92000000e+02, -1.76783943e-01],
#        [ 1.45753925e+01,  9.70000000e+01, -0.00000000e+00, ...,
#          8.93090907e+01,  4.70000000e+01,  3.72940012e-01],
#        [ 1.38604525e+01,  9.20000000e+01, -0.00000000e+00, ...,
#          8.81322858e+01,  3.80000000e+01,  5.92286185e-01]])}

# %%
CVD     = 1252
non_CVD = 1228
Y = np.zeros((CVD+non_CVD,1))
Y[:CVD] = 1

# %%
X_train, X_test, Y_train, Y_test = train_test_split(mat['Feature_all_sig'], Y, test_size=0.2)

# %%
print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
# Out:
# (1984, 33) (1984, 1) (496, 33) (496, 1)

# %%
Y_train = np.reshape(Y_train, (1984,1))
Y_test  = np.reshape(Y_test,  (496,1))
print(Y_train.shape, Y_test.shape)
# Out:
# (1984, 1) (496, 1)

# %%
EN = ElasticNet(alpha=10.0, l1_ratio=0.5, max_iter=1000)
EN.fit(X_train, Y_train)
# Out:
# ElasticNet()

# %%
EN.coef_
# EN.intercept_
# Out:
# array([ 0.00000000e+00,  2.06105698e-03, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -6.34701039e-05,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#        -1.01793867e-03, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -8.19072288e-03,  0.00000000e+00,
#        -0.00000000e+00])

# %%
EN.predict(X_test).shape
# Out:
# (496,)

# %%
Y_pred = np.round(EN.predict(X_test))
Y_pred = np.reshape(Y_pred, (496,1))

# %%
print(Y_pred.shape, Y_test.shape, (Y_pred-Y_test).shape)
# Out:
# (496, 1) (496, 1) (496, 1)

# %%
1 - np.sum(abs(Y_pred-Y_test)) / Y_pred.shape[0]
# Out:
# 0.6189516129032258
